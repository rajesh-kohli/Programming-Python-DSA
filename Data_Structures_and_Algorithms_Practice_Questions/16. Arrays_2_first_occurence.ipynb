# %% [markdown]
# Given an array of N integers, and an integer T, design an algorithm to find the index of the first occurrence of T in the given array.
#
#
#
# note : output -1 if T is not present in the given array.
#
#  Input : N = 5 ; T = 20
#
#
# 10 20 30  10 20
#
# Output : 1

# %%
### First occurence

n = int(input())
t = int(input())

arr = []
for _ in range(n):
    number = int(input())
    arr.append(n)

# %%
## instead of the above, we can do list comprehension

n = int(input())
t = int(input())
arr = [int(input()) for _ in range(n)]
print(arr)
# Out:
# [10, 20, 30, 40]

# %%
def first_occ(arr:list[int], t:int)->int:
    for i, num in enumerate(arr):
        if num == t:
            return i
    return -1

# for i in range(len(arr)):
#     num = arr[i]

print(first_occ(arr, t))
# Out:
# 1

# %%
## there is a built-in function as well for getting the index of the built-in function

arr.index(t) ## just pass the target, if target is present, it will return the index
## and if target is not in the list, it gives back value error, to handle this, we do try except block
# Out:
# 1

# %%
try:
    print(arr.index(t))
except:
    print(-1)
# Out:
# 1
