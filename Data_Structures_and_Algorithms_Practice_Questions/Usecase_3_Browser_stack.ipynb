# %% [markdown]
# ## Stack
#     - two operations;
#         - Push
#         - Pop
# ## take any webssite, the browser history would be in a stack format
#      - the most recent website URL would be on the top of the stack
#
# ### Write a search function - whenever you search a URL, that URL should get pushed into the stack -
# #### and then write a remove browser histoty that should remove all the history all at once and not one by one. For that you write a for loop
#    def Browser_stack():
#         search("www.google.com") --> push on the stack
#         search("cricbuzz.com") -->
#
#     def remove_browser_history():
#             stack empty --> remove all the URL present in the stack
#
#     for creating a stack --> use list data structure

# %% [markdown]
# ## Browser stack use case
#
# ## First do stack creation
# ### Push and Pop operation
# #### we are creating the stack with the help of list (LIFO)
#
# stack = []
# def push(element):
#     stack.append(element)
#     return stack
# def pop(element):
#     if len(stack) == 0:
#         print("can not find )

# %%
stack = []
def push(element):
    stack.append(element)
    return stack
def pop():
    if len(stack) == 0:
        print("Cannot remove element because stack is empty")
    else:
        stack.pop(-1)
        return stack

# %%
push(10)
# Out:
# [10]

# %%
push(20)
# Out:
# [10, 20]

# %%
push(30)
# Out:
# [10, 20, 30]

# %%
push(40)
# Out:
# [10, 20, 30, 40]

# %%
pop()
# Out:
# [10, 20, 30]

# %%
pop()
# Out:
# [10, 20]

# %%
pop()
# Out:
# [10]

# %%
pop()
# Out:
# []

# %%
pop()
# Out:
# Cannot remove element because stack is empty

# %%
### Now let's create a browser stack

Browser_stack = []
def search_url(url):
    Browser_stack.append(url)
    return Browser_stack
def remove_history():
    for i in Browser_stack:
        Browser_stack.pop(0)
    return Browser_stack

# %%
search_url("https://swayam-sso.swayam2.ac.in/signin?response_type=code&client_id=swayam-node1-production&redirect_uri=%2Fe-learning%2Fcourse%2Fnoc26_cs97&state=npWTcRldtEZP5lmZ9z90V5EGtcrv9i")
# Out:
# ['https://swayam-sso.swayam2.ac.in/signin?response_type=code&client_id=swayam-node1-production&redirect_uri=%2Fe-learning%2Fcourse%2Fnoc26_cs97&state=npWTcRldtEZP5lmZ9z90V5EGtcrv9i']

# %%
search_url("https://www.sarvam.ai/")
# Out:
# ['https://swayam-sso.swayam2.ac.in/signin?response_type=code&client_id=swayam-node1-production&redirect_uri=%2Fe-learning%2Fcourse%2Fnoc26_cs97&state=npWTcRldtEZP5lmZ9z90V5EGtcrv9i',
#  'https://www.sarvam.ai/']

# %%
search_url("https://openai.com/")
# Out:
# ['https://swayam-sso.swayam2.ac.in/signin?response_type=code&client_id=swayam-node1-production&redirect_uri=%2Fe-learning%2Fcourse%2Fnoc26_cs97&state=npWTcRldtEZP5lmZ9z90V5EGtcrv9i',
#  'https://www.sarvam.ai/',
#  'https://openai.com/']

# %%
remove_history(Browser_stack)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 remove_history(Browser_stack)
#
# TypeError: remove_history() takes 0 positional arguments but 1 was given
