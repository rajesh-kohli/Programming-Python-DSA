# %%
ch = "d"
print(ch)
print(ord(ch))
# Out:
# d
# 100

# %%
ch = "D"
print(ch)
print(ord(ch))
# Out:
# D
# 68

# %%
n = 65
print(n)
print(chr(n))
# Out:
# 65
# A

# %% [markdown]
# #### Use chr() function to find the character from integer value
# #### use ord() function to find the integer value from character

# %%
n = 122
print(n)
print(chr(n))
# Out:
# 122
# z

# %%
ch = input()

if ord(ch) >= 65 and ord(ch) <=90:
    print("Uppercase")
